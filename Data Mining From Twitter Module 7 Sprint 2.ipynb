# %%
import tweepy
from tweepy import OAuthHandler
import csv
import json
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
import numpy as np
from pandas import Series, DataFrame
from pylab import rcParams
import seaborn as sb
from numpy.random import randn

# %%
consumer_key='JB5EsFoRmXTVzsBj4I1X4Qdtm'
consumer_secret='OertJZvTETdg3U7AJbcz0gZEmlOPRzS2XY8KMBmKPiXrReRgCx'
access_token='1291472154572324864-TNAcCRnHSKUi07E7QMrvQWPiUyLU77'
access_secret='Nzyx2N1vn4sILIa1N3wyYGCVBDPP4HlsCDJi5ACw91vQY'

# %%
auth = tweepy.auth.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
csvFile = open('twitter_data_analysis2020-08-10-11.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,
                           q = "google",
                           since = "2020-08-09",
                           until = "2020-08-10",
                           lang = "en").items():
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print(tweet.created_at, tweet.text)
    
csvFile.close()
# Out:
# 2020-08-09 23:59:59 San Jose: Baltoy 97.8% (15/15/14) CP:268 (L12) Extrasensory/Psybeam till 17:31:49 (verified) (31m 49s).https://t.co/SOSHhCcbgU
# 2020-08-09 23:59:59 RT @btcturkpro: 1️⃣ Register in minutes,
# 2️⃣ Deposit cryptocurrencies,
# 3️⃣ Start trading #Bitcoin and cryptocurrencies!
#
# #btcturkpro is no…
# 2020-08-09 23:59:58 @proudyoshi Thanks for contacting us – YouTube confirms that views are real. You may see views slow down, freeze, o… https://t.co/oXEMNnqDXL
# 2020-08-09 23:59:58 RT @rmbyrne: 10 Ways to Use Google Earth in Your Classroom https://t.co/IYxOjS8x78
# 2020-08-09 23:59:58 @ExchangeTDN @ChrisSurano @TheJamesBolivar @DrBoeing @MrStache9 @Pick_A_Lane @PLHCrawford @ForbesLorne @RRidley11… https://t.co/p97k5FT5qT
# 2020-08-09 23:59:57 @dale_runkle Just google the headline. I read it
# 2020-08-09 23:59:55 RT @chrisg00004: @alaskan_patriot @realDonaldTrump He gave that speech at Whirlpool, where they make washing machines. Think money launderi…
# ...

# %%
tweets_data_path="twitter_data_analysis2020-08-10-11.csv"
tweets_data=[]


tweets_file=open(tweets_data_path,"r")

for line in tweets_data_path:
    try:
        tweet=json.loads(line)
        tweets_data.append(tweet)
    except:
        continue
tweets=pd.DataFrame()
tweets["text"]=map(lambda tweet:tweet['text'],tweets_data)
tweets["lang"]=map(lambda tweet:tweet['lang'],tweets_data)
tweets["country"]=map(lambda tweet:tweet['place']['country']if[place]!=None else None,tweets_data)

tweets_by_lang=tweets['lang'],value_counts()

fig,ax=plt.subplots()
ax.tick_params(axis='x',labelsize=15)
ax.tick_params(axis='y',labelsize=10)
ax.set_xlabel('Languages',fontsize=15)
ax.set_ylabel('Number of Tweets',fontsize=15)
ax.set_title('Top 5 Languages',fontsize=15,fontweight='bold')
tweets_by_lang[:5].plot(ax=ax,kind='bar',color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-d675545199e9> in <module>
#      12         continue
#      13 tweets=pd.DataFrame()
# ---> 14 tweets["text"]=map(lambda tweet:tweet['text'],tweets_data)
#      15 tweets["lang"]=map(lambda tweet:tweet['lang'],tweets_data)
#      16 tweets["country"]=map(lambda tweet:tweet['place']['country']if[place]!=None else None,tweets_data)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2997         """
#    2998
# -> 2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# ...

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %%
address = open("C:\\Users\\Student\\anaconda3\\twitter_data_analysis2020-08-10-11.csv")

df = pd.read_csv(address, parse_dates = {"datetime":[0,1]}, index_col= "datetime")

df.head
# Out:
# <bound method NDFrame.head of                                                    At the Heart of It: Cardiac Inflammation the Next Virus Hurdle for College Leaders https://t.co/DTWNV4kK9k… https://t.co/zxEoPvTVSG  \
# datetime
# 2020-08-10  11:25 1292723795132690433               RT @FreelandCO5: Like you, my family means eve...
# 2020-08-10  11:25 1292716532745801729               This is just a reminder that every person in t...
# 2020-08-10  11:25 1292709921708888065               #MedicareForAll - If you don't agree that is y...
# 2020-08-10  11:25 1292703432986378242               RT @missy5moody: @siencraig @JustinSwartz63 Ca...
# 2020-08-10  11:25 1292699785993031680               @stuartpstevens @TheRickWilson Let's list all ...
# ...                                                                                               ...
# 2020-08-09 23:41:57 b"RT @MrsParkShine: I've be...                                                NaN
# ...

# %%
df = df.sample(n=100, random_state=25, axis=0)
plt.xlabel("Date Time")
plt.ylabel("Retweets Per Second")

plt.title("Twitter Data Analysis")
df.plot()
